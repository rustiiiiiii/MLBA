# %%
# code used for obtaining features

#import libraries


import numpy as np 
import pandas as pd 
import system
import os
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.feature_selection import VarianceThreshold
from sklearn.model_selection import KFold   
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier, export_graphviz
from sklearn import metrics
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# %%
def principleCA(X, comp):

    X_transform = PCA(n_components=comp).fit_transform(X)
    # print("number of features", len(X_transform.columns))

    return pd.DataFrame(data=X_transform)

# %%
#loading dataset
#train_path = '/content/drive/MyDrive/mlba_2_data/kaggle_train.csv'
#test_path = '/content/drive/MyDrive/mlba_2_data/kaggle_test.csv'
train_data = pd.read_csv('kaggle_train.csv')
test_data  = pd.read_csv('kaggle_test.csv')

scaler = StandardScaler()
X3 = test_data.iloc[:,:]
X3 = X3.drop(['ID'],axis=1) # removes ID column


X1 = train_data.iloc[:,:]
X1.drop(["ID"],axis=1,inplace=True)
y = X1.iloc[:,0] # consists of the label column
X1 = X1.drop(['Labels'],axis=1) # removes label  column

X1
# Out:
#         ACAN      AGER     ALPK1    ANKRD17     APOB      APPL1      APPL2  \
# 0    13.6584   88.0205  402.5420  1424.2625   3.7940  1001.2330   508.0148
# 1    22.0844   86.3807  690.4861  2226.3285  20.4071   486.9744  1448.0640
# 2    32.7422   53.0820  128.4882  1073.0497   0.0000   654.8431   492.6206
# 3    22.7975   42.1175  634.0804  3285.5487   0.0000   574.9614   513.9104
# 4     2.5000  134.0625  532.1875   936.5625   0.0000  1933.4375   679.3750
# ..       ...       ...       ...        ...      ...        ...        ...
# 237  92.7039   43.6988  403.5895  2001.4046   0.0000  1378.6968   858.6812
# 238  38.0381   64.5365  238.0586  1686.0704   0.0000   733.8359   984.2890
# 239  21.2202   56.1941  542.6859  1887.0223   0.0000  1254.7402   873.5632
# 240   6.6194   77.7783  702.4867  1428.1415   0.0000   874.5918   884.5210
# 241  21.4563   46.0782  401.3377  1572.2869   0.0000  1709.4663   747.8036
#
# ...

# %%
scaler = StandardScaler()
X  = pd.DataFrame(scaler.fit_transform(X1))
X4  = pd.DataFrame(scaler.fit_transform(X3))
X
# Out:
#           0         1         2         3         4         5         6    \
# 0   -0.419883  0.004093 -0.213773 -0.451306 -0.134639 -0.099715 -0.786202
# 1   -0.311509 -0.022046  0.917877  0.717234  0.199860 -1.283249  1.001411
# 2   -0.174431 -0.552835 -1.290832 -0.962992 -0.211030 -0.896910 -0.815476
# 3   -0.302338 -0.727611  0.696197  2.260424 -0.211030 -1.080752 -0.774991
# 4   -0.563401  0.738012  0.295747 -1.161842 -0.211030  2.045693 -0.460341
# ..        ...       ...       ...       ...       ...       ...       ...
# 237  0.596787 -0.702405 -0.209656  0.389539 -0.211030  0.768993 -0.119369
# 238 -0.106316 -0.370247 -0.860209 -0.069875 -0.211030 -0.715113  0.119489
# 239 -0.322625 -0.503227  0.337007  0.222894 -0.211030  0.483715 -0.091069
# 240 -0.510418 -0.159170  0.965041 -0.445654 -0.211030 -0.391172 -0.070232
# 241 -0.319588 -0.664477 -0.218506 -0.235647 -0.211030  1.530238 -0.330216
#
#           7         8         9    ...       308       309       310  \
# ...

# %%
X2 = principleCA(X, 0.95)
X2
# Out:
#           0         1         2         3         4         5         6    \
# 0    0.328107  0.176721 -2.691159 -1.113763  4.674899 -1.874235 -1.698770
# 1   -0.320623 -3.815432 -0.275081  0.533114 -1.988049  3.168554  0.403423
# 2   -3.486598  4.039111 -1.319757 -4.157620  6.282518 -2.912695  0.351944
# 3    7.393808 -6.603599 -4.609422  0.144954  0.363931  2.605038 -2.264625
# 4    1.945278 -1.657228 -1.089911  1.843192 -0.476570 -1.925483 -0.851778
# ..        ...       ...       ...       ...       ...       ...       ...
# 237  0.780146 -7.421469  2.194601 -2.931270 -1.961195  5.851483  0.339919
# 238 -0.465229 -4.184930 -5.894930 -1.463805 -0.687134  2.810082  0.013010
# 239  1.771323 -3.515055 -2.241932  0.644775  0.831932 -0.188900  0.512423
# 240 -4.202501  4.689817  4.355946  4.988063  0.058316  0.429022 -0.130155
# 241  1.096816 -0.301071 -3.132587 -0.057387  3.607002 -0.869453 -1.740371
#
#           7         8         9    ...       118       119       120  \
# ...

# %%
X5 = principleCA(X4)
X5
# Out:
#            0          1          2         3         4         5          6   \
# 0   -3.697826   0.299956   2.207727 -3.477715  1.066974  0.841137  -0.517149
# 1    5.058484  -2.449826  -2.278917 -2.179100 -2.593611 -0.275969   2.886748
# 2   16.762376  -5.256562   8.663467  3.496938 -1.778744  5.386717  -4.430329
# 3   -5.634408  -0.640664  -2.228072 -0.908075 -0.002780 -2.325676  -0.069779
# 4   -5.375608  -0.416391   3.359689 -6.525660  0.237728 -2.096916   0.337972
# ..        ...        ...        ...       ...       ...       ...        ...
# 57  -5.591692  10.774759  10.732029  5.428452 -0.968946  3.248656  19.441627
# 58  -3.623675  -2.182339  -2.171760  0.755220 -0.887118 -4.781741   0.485526
# 59   3.539499  -2.430332  -3.753810 -1.131737 -0.069203  2.494744   0.796939
# 60  -6.508953   7.079880   2.669888 -5.886860  1.352215  0.833238  -5.510156
# 61  -3.814234  -2.153275   3.978358 -1.791500  4.753035  3.083280  -0.456838
#
# ...

# %%
pred_df = pd.DataFrame(X2)
pred_df.to_csv("PCA_train.csv")
